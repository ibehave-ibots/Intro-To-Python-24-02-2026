# %% [markdown]
# 1. Python Variables
#    1. Different types
#    2. Operations we can do with them
#    3. What is not allowed
# 2. Brief intro to Numpy
#    1. Load a .npy file
#    2. Some basic methods we can use

# %%
age = 25
age
# Out:
# 25

# %%
a = 5
a
# Out:
# 5

# %%
type(a)
# Out:
# int

# %%
a = 5.0
type(a)
# Out:
# float

# %%
b = "Hi, I am Sangeetha"
type(b)
# Out:
# str

# %%
is_available = True
type(is_available)
# Out:
# bool

# %% [markdown]
# Different operations

# %%
a = 5
b = 10.
a + b
# Out:
# 15.0

# %%
a - b
# Out:
# -5.0

# %%
a = "Hello"
b = " Sangeetha"

# %%
a + b
# Out:
# 'Hello Sangeetha'

# %%
a - b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 a - b
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
ages = [5, 10, 15, 25]
type(ages)
# Out:
# list

# %%
ages * 2
# Out:
# [5, 10, 15, 25, 5, 10, 15, 25]

# %% [markdown]
# Numpy intro

# %%
import numpy as np

# %%
spks = np.load("spikes.npy")

# %%
type(spks)
# Out:
# numpy.ndarray

# %%
np.size(spks)
# Out:
# 721

# %%
np.min(spks)
# Out:
# np.float64(0.05400352133165143)

# %%
np.max(spks)
# Out:
# np.float64(298.4843451836275)
